# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
def generate_uniform_distribution(bottom, ceiling, count):
    data = np.random.randint(bottom, ceiling, count)
    return data
generate_uniform_distribution(10,60,1000)
# Out:
# array([12, 34, 10, 24, 41, 40, 56, 29, 25, 59, 37, 35, 44, 42, 50, 54, 53,
#        31, 21, 59, 50, 10, 52, 24, 28, 59, 53, 57, 33, 56, 21, 58, 41, 45,
#        25, 40, 23, 58, 56, 16, 56, 59, 36, 21, 47, 10, 48, 31, 37, 57, 20,
#        30, 40, 11, 39, 34, 50, 38, 14, 17, 37, 24, 39, 25, 51, 49, 56, 26,
#        37, 41, 28, 54, 56, 51, 18, 16, 19, 40, 58, 32, 31, 16, 32, 42, 29,
#        14, 28, 51, 17, 22, 28, 19, 12, 42, 22, 32, 31, 21, 50, 34, 32, 30,
#        50, 36, 46, 30, 58, 32, 55, 57, 28, 33, 19, 14, 53, 34, 50, 52, 55,
#        59, 45, 45, 31, 17, 39, 18, 23, 53, 25, 35, 39, 13, 50, 10, 50, 27,
#        28, 47, 43, 25, 38, 36, 10, 21, 25, 40, 44, 28, 50, 45, 59, 10, 42,
#        27, 30, 35, 20, 21, 27, 54, 19, 26, 23, 36, 25, 29, 35, 51, 49, 46,
#        15, 39, 37, 49, 12, 15, 26, 50, 39, 53, 10, 53, 44, 48, 39, 53, 10,
#        33, 18, 23, 12, 22, 54, 47, 30, 39, 26, 54, 36, 13, 13, 57, 44, 55,
# ...

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
#1. Call your function with 2 sets of params below:
    # a. bottom=10, ceiling=15, count=100
data_1 = generate_uniform_distribution(10, 15, 100)

# %%
    # b. bottom=10, ceiling=60, count=1,000
data_2 = generate_uniform_distribution(10, 60, 1000)

# %%
# Histogram for random numbers generated with numpy
plt.subplot(1, 2, 1)
plt.hist(data_1, bins=10, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Count')
plt.xlim(10, 15)
plt.ylim(0,100)

# Histogram for random numbers generated with numpy
plt.subplot(1, 2, 2)
plt.hist(data_2, bins=10, color='orange', alpha=0.7, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Count')
plt.xlim(10, 60)
plt.ylim(0,100)

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# first array has less values, so the probability of generating the same number muktiple times os lower than in array 2. So, the frequency/count of the values is lower in data 1 than data 2

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
# define our function:

def generate_uniform_norm(mean, std_dev, n):
    data = norm.rvs(loc=mean, scale=std_dev, size=n)
    return data

# case A
mean = 10         
std_dev = 1      
n = 1000          

data_3 = generate_uniform_norm(mean, std_dev, n)

# %%
# Define parameters
mean = 10         
std_dev = 50      
n = 1000          

# Generate normally distributed numbers using scipy.stats.norm
data_4 = generate_uniform_norm(mean, std_dev, n)

# %%
# Histogram for random numbers generated with spicy norm
plt.subplot(1, 2, 1)
plt.hist(data_3, bins=100, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Count')

# Histogram for random numbers generated with spicy norm
plt.subplot(1, 2, 2)
plt.hist(data_4, bins=100, color='orange', alpha=0.7, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Count')

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# # the data is highly concentrated around the mean in the first plot, since the standard deviation is smaller than the second data group

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
df = pd.read_csv('vehicles.csv')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
fuel_barrels = df['Fuel Barrels/Year']
plt.figure(figsize=(10, 6))
plt.hist(fuel_barrels, bins=10, color='lightgreen', edgecolor='black', alpha=0.7)
plt.title('Histogram of Fuel Barrels/Year')
plt.xlabel('Fuel Barrels/Year')
plt.ylabel('Count')
plt.grid(axis='y', alpha=0.75)
plt.axvline(fuel_barrels.mean(), color='red', linestyle='dashed', linewidth=1, label='Mean')
plt.legend()
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
emissions = df['CO2 Emission Grams/Mile']
plt.figure(figsize=(10, 6))
plt.hist(emissions, bins=10, color='lightgreen', edgecolor='black', alpha=0.7)
plt.title('Histogram of CO2 emissions')
plt.xlabel('CO2 grams/mile')
plt.ylabel('Count')
plt.grid(axis='y', alpha=0.75)
plt.axvline(emissions.mean(), color='red', linestyle='dashed', linewidth=1, label='Mean')
plt.legend()
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
mpg = df['Combined MPG']
plt.figure(figsize=(10, 6))
plt.hist(mpg, bins=10, color='lightgreen', edgecolor='black', alpha=0.7)
plt.title('Histogram of Combined MPG')
plt.xlabel('combined MPG')
plt.ylabel('Count')
plt.grid(axis='y', alpha=0.75)
plt.axvline(mpg.mean(), color='red', linestyle='dashed', linewidth=1, label='Mean')
plt.legend()
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
#all of them are nearly normally distributed since all the data accumulates around the mean in the center and expands following a certain pattern

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# Define the function to generate exponentially distributed numbers
def generate_exponential_data(mean, n):
    """
    Generate a list of numbers that are exponentially distributed with a given mean.
    
    Args:
        mean (float): The mean (scale) of the exponential distribution.
        n (int): The number of numbers to generate.
        
    Returns:
        list: A list of exponentially distributed numbers.
    """
    # The scale parameter of the exponential distribution is the same as the mean
    scale = mean
    exponential_data = np.random.exponential(scale, n)
    
    return exponential_data

# %%
# 1. Use the function to generate two number sequences with the size of 10 and 100.

data_5 = generate_exponential_data(10, 10)
data_6 = generate_exponential_data(10,100)

# 2. Plot the data
# Histogram for random numbers generated with spicy norm
plt.subplot(1, 2, 1)
plt.hist(data_5, bins=30, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Count')
plt.xlim(0,10)

# Histogram for random numbers generated with spicy norm
plt.subplot(1, 2, 2)
plt.hist(data_6, bins=100, color='orange', alpha=0.7, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Count')
plt.xlim(0,100)

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
from scipy.stats import expon

# Given parameters
mean_time = 10
scale = mean_time

# Probability P(X < 15)
prob_less_than_15 = expon.cdf(15, scale=scale)
print('Probability of spending less than 15 minutes:', prob_less_than_15)
# Out:
# Probability of spending less than 15 minutes: 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# Probability P(X > 15) use sf() that calculates the function f(x) = e ** (-lambda * x) with x = 15 in this case
prob_more_than_15 = expon.sf(15, scale=scale)
print('Probability of spending more than 15 minutes:', prob_more_than_15)
# Out:
# Probability of spending more than 15 minutes: 0.22313016014842982
